# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6C42-E479
#
#  Directory of C:\Users\PhucCoi\Documents\PYTHON
#
# 01/17/2019  03:38 PM    <DIR>          .
# 01/17/2019  03:38 PM    <DIR>          ..
# 01/17/2019  03:38 PM    <DIR>          .git
# 01/17/2019  03:35 PM    <DIR>          .idea
# 01/17/2019  02:53 PM    <DIR>          .ipynb_checkpoints
# 01/15/2019  01:28 PM         1,000,571 AFFILIATE_Estimated_revenue_2019-01-11.txt
# 01/17/2019  03:02 PM           931,730 AFFILIATE_Estimated_revenue_2019-01-12.txt
# 01/15/2019  01:28 PM         6,861,865 AFFILIATE_Owner_basic_2019-01-11.txt
# 01/17/2019  03:02 PM         6,325,416 AFFILIATE_Owner_basic_2019-01-12.txt
# 01/15/2019  01:30 PM         1,453,065 AFF-TH_Estimated_revenue_2019-01-11.txt
# 01/17/2019  03:03 PM         1,488,814 AFF-TH_Estimated_revenue_2019-01-12.txt
# 01/15/2019  01:30 PM         8,326,470 AFF-TH_Owner_basic_2019-01-11.txt
# ...

# %% [markdown]
# # Report dates: 2019-01-15T08:00:00Z to 2019-01-17T06:45:36.138421Z

# %%
import pandas as pd
data = pd.read_table("Music_metadata_a2_15-17.txt",sep=",")
print(data.shape)
data.head()
# Out:
# (149391, 40)
#       video_id                channel_id                channel_display_name  \
# 0  ---2q7vcZGU  UC9s1Pvm0U8Gg8mRavZhVXdg                        Ca sĩ Kha Ly
# 1  ---bCrhHfjk  UCY9k0sZyd5yzJiIDgF_6CSQ                     Karaoke OrganBM
# 2  --2kMDApgQw  UC_ccTaL4kIuAkKOau-hJz6w                             Mic Hát
# 3  --4IP3TCenU  UCIL3km0UFKmyIvEqpvsEYFA                   JET Entertainment
# 4  --59vmjqLl8  UCjWqoVsnUiPUqsBscOFFsaw  VHOPE - Mục Vụ Truyền Thông Cơ Đốc
#
#          time_uploaded       time_published  \
# 0  2016/06/23 08:48:24  2016/06/24 08:19:42
# 1  2018/08/06 23:40:00  2018/08/12 16:00:00
# 2  2018/07/22 23:25:48  2018/07/28 17:00:01
# 3  2015/02/26 04:49:30  2015/02/26 18:39:06
# 4  2017/06/15 07:44:11  2017/06/15 15:30:01
#
#                                          video_title  video_length  views  \
# 0  Thanh Duy say đắm ngắm nhìn Kha Ly trổ tài đàn...            35  56181
# ...

# %%
data.columns
# Out:
# Index(['video_id', 'channel_id', 'channel_display_name', 'time_uploaded',
#        'time_published', 'video_title', 'video_length', 'views', 'comments',
#        'video_privacy_status', 'video_url', 'category', 'embedding_allowed',
#        'ratings_allowed', 'comments_allowed', 'claim_origin', 'content_type',
#        'upload_source', 'claimed_by_this_owner', 'claimed_by_another_owner',
#        'other_owners_claiming', 'offweb_syndicatable', 'claim_id', 'asset_id',
#        'custom_id', 'effective_policy', 'third_party_video_id',
#        'in_video_ads_enabled', 'third_party_ads_enabled',
#        'display_ads_enabled', 'sponsored_cards_enabled', 'overlay_ads_enabled',
#        'nonskippable_video_ads_enabled', 'long_nonskippable_video_ads_enabled',
#        'skippable_video_ads_enabled', 'prerolls_enabled', 'midrolls_enabled',
#        'postrolls_enabled', 'isrc', 'eidr'],
#       dtype='object')

# %%
data.views.sum()
# Out:
# 19907778979

# %%
19891285018 - 19907778979
# Out:
# -16493961

# %%
import pandas as pd
data = pd.read_table("Music_metadata_a2_14-16.txt",sep=",")
print(data.shape)
data.head()
# Out:
# (149448, 40)
#       video_id                channel_id                channel_display_name  \
# 0  ---2q7vcZGU  UC9s1Pvm0U8Gg8mRavZhVXdg                        Ca sĩ Kha Ly
# 1  ---bCrhHfjk  UCY9k0sZyd5yzJiIDgF_6CSQ                     Karaoke OrganBM
# 2  --2kMDApgQw  UC_ccTaL4kIuAkKOau-hJz6w                             Mic Hát
# 3  --4IP3TCenU  UCIL3km0UFKmyIvEqpvsEYFA                   JET Entertainment
# 4  --59vmjqLl8  UCjWqoVsnUiPUqsBscOFFsaw  VHOPE - Mục Vụ Truyền Thông Cơ Đốc
#
#          time_uploaded       time_published  \
# 0  2016/06/23 08:48:24  2016/06/24 08:19:42
# 1  2018/08/06 23:40:00  2018/08/12 16:00:00
# 2  2018/07/22 23:25:48  2018/07/28 17:00:01
# 3  2015/02/26 04:49:30  2015/02/26 18:39:06
# 4  2017/06/15 07:44:11  2017/06/15 15:30:01
#
#                                          video_title  video_length  views  \
# 0  Thanh Duy say đắm ngắm nhìn Kha Ly trổ tài đàn...            35  56174
# ...
